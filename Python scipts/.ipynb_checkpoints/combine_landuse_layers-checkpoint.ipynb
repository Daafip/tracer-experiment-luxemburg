# %%
import geopandas as gpd
import pandas as pd
import glob
import os
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
path = os.path.dirname(os.getcwd()) +  "\\GIS\\Files\\land_use_sub_basin_mechelbach_split_*.gpkg"

# %%
files = glob.glob(path)

# %%
lst_layers = []
for i, file in enumerate(files):
    gdf = gpd.read_file(file)
    gdf = gdf[["Landuse",'area_ha']]
    gdf["area_ha"] = gdf["area_ha"] / gdf["area_ha"].sum() * 100
    section_name = file.split("_")[-1].split(".")[0]
    gdf.rename(columns={"area_ha":section_name, "Landuse":"percentage_per_landuse"},inplace=True)
    lst_layers.append(gdf.set_index("percentage_per_landuse").T)

# %%
df = pd.concat(lst_layers).fillna(0)
df.index = df.index.astype(int)
df.sort_index(inplace=True)
df.to_excel("combined_landuse_percentages_per_catchment.xlsx")

# %%
lst_layers_ha = []
for i, file in enumerate(files):
    gdf = gpd.read_file(file)
    gdf = gdf[["Landuse",'area_ha']]
    # gdf["area_ha"] = gdf["area_ha"] / gdf["area_ha"].sum() * 100
    section_name = file.split("_")[-1].split(".")[0]
    gdf.rename(columns={"area_ha":section_name, "Landuse":"ha_per_landuse"},inplace=True)
    lst_layers_ha.append(gdf.set_index("ha_per_landuse").T)

# %%
df_ha = pd.concat(lst_layers_ha).fillna(0)
print(f'Total area is {df_ha.sum(axis=1).sum():.3f} ha')
# Out:
# Total area is 1070.082 ha

# %%
df_ha['total_area'] = df_ha.sum(axis=1)
df_ha.index = df_ha.index.astype(int)
df_ha.sort_index(inplace=True)

# %%
subbasin_file = os.path.dirname(os.getcwd()) + "\\GIS\\Files\\sub_basins_mechelbach_dissolved2.gpkg"

# %%
gdf = gpd.read_file(subbasin_file)
df_area = gdf[['section_number','area_ha']].set_index('section_number')
df_area.sort_index(inplace=True)
print(f'Total area is {df_area.sum(axis=1).sum():.3f} ha')
# Out:
# Total area is 1070.847 ha

# %%
df_area.to_excel("area_per_catchment.xlsx")

# %%
df_Q = pd.read_excel("results_Q.xlsx")
df_Q.set_index("Section",inplace=True)

# %%
df_TWI = pd.read_csv("TWI per catchment2.csv")[['section_number','TWI__average','TWI__sum']]
df_TWI = df_TWI.set_index("section_number")
df_TWI.index = df_TWI.index.astype(int)
df_TWI.sort_index(inplace=True)

# %%
df_TWI
# Out:
#                 TWI__average       TWI__sum
# section_number
# 1                   9.796246  868701.729205
# 2                   9.033403    3008.123239
# 3                   9.937165  551771.029745
# 4                   9.427233  307214.666424
# 5                   9.673257  172135.602616
# 6                   8.467215    2709.508724
# 7                   8.855292    3365.010994
# 8                   8.781323  168566.284671
# 9                   9.781069  166190.142896
# 10                 11.741502   29858.639133
# 11                  4.797486       4.797486
# 12                  9.731462  294863.287630
# 13                  8.838139   18462.871476
# 14                  9.963468  173404.203415
# 15                  9.680804  210431.633077
# 17                  9.800516   51687.921154
# 19                  9.028921  290415.254631
# 20                  9.329589    5019.319047
# 21                  9.230136   58906.726554
# 22                  9.526452   40506.471941
# 23                  9.079197   12029.936228
# 24                  9.910750  191882.035541
# 25                  9.437349   30218.392108
# 26                  9.771860  414707.963010
# 27                  9.659207   72666.213122

# %%
df_combined = pd.concat([df_Q, df_area,df,df_TWI],axis=1)

# %%
# l/s / ha =? *10^-3 = m^3/s/ha -> 10-7 m^3/s/m^2= 10-7m/s = 10-4mm/s = 10-4 * 86400 mm/d
df_combined['Q_specific'] = df_combined['Q'] / df_combined['area_ha'] * 10**(-4) * 86400

# %%
df_combined.sort_values("area_ha",ascending=False)
# Out:
#          Q     area_ha      Forest  Settlement  Agriculture  Transport  \
# 1   190.00  221.691019   16.286943    4.709982    73.883741   2.802838
# 3    93.10  138.814514   74.066660    2.222837    21.463650   2.010968
# 26   14.56  106.096899   14.125312    1.702600    81.607673   1.910632
# 4     3.69   81.469700   60.894703    0.000000    34.496244   2.575278
# 19   10.51   80.412148   36.154917    5.894247    53.081109   3.545238
# 12    5.66   75.749650   20.789841   13.979297    60.671524   3.579617
# 15   13.73   54.342278   50.890452   29.656425    14.790140   3.098598
# 24    3.35   48.402266    8.333333   10.416667    77.083333   4.166667
# 8    73.22   47.989809   82.370119    0.000000    14.726520   2.903361
# 5    88.48   44.487336   91.431068    0.000000     4.062249   2.433733
# 14   41.80   43.509804   45.051042    0.485662    52.091126   2.372170
# 9     2.37   42.477328   46.423833    0.000000    51.759272   1.816895
# 27    0.48   18.807402   36.990038    5.250301    55.287815   2.471846
# 21    0.00   15.954921   38.391139    0.743454    58.430545   2.434862
# 17   41.21   13.184937   46.153846    0.000000    53.846154   0.000000
# 22   21.22   10.629949   44.014359    0.000000    53.398856   2.586785
# 25   17.24    8.004959   67.171491    0.000000    31.727179   1.101330
# 10   68.49    6.357472   23.245910    0.000000    69.790712   2.535808
# 13   62.83    5.222478   74.885973    0.000000    21.174419   3.939608
# 23    0.00    3.312484   41.031639    0.000000    54.963615   4.004747
# 20   23.19    1.344993   79.122844    0.000000    20.294538   0.582619
# 7     0.00    0.949996    5.985079    0.000000    85.419034   8.595886
# 2    96.90    0.832497   33.569743    0.000000    62.096711   4.333545
# 6    75.59    0.799997   97.015456    0.000000     2.487543   0.497001
# 11    0.00    0.002500  100.000000    0.000000     0.000000   0.000000
# 16     NaN         NaN         NaN         NaN          NaN        NaN
# 18   26.69         NaN         NaN         NaN          NaN        NaN
#
#     Natural surfaces     Water  TWI__average       TWI__sum   Q_specific
# 1           2.316497  0.000000      9.796246  868701.729205     7.404901
# 3           0.235885  0.000000      9.937165  551771.029745     5.794668
# 26          0.653782  0.000000      9.771860  414707.963010     1.185693
# 4           2.033775  0.000000      9.427233  307214.666424     0.391331
# 19          1.324490  0.000000      9.028921  290415.254631     1.129262
# 12          0.979721  0.000000      9.731462  294863.287630     0.645579
# 15          1.398387  0.165999      9.680804  210431.633077     2.182963
# 24          0.000000  0.000000      9.910750  191882.035541     0.597989
# 8           0.000000  0.000000      8.781323  168566.284671    13.182399
# 5           2.072950  0.000000      9.673257  172135.602616    17.183929
# 14          0.000000  0.000000      9.963468  173404.203415     8.300474
# 9           0.000000  0.000000      9.781069  166190.142896     0.482064
# 27          0.000000  0.000000      9.659207   72666.213122     0.220509
# 21          0.000000  0.000000      9.230136   58906.726554     0.000000
# 17          0.000000  0.000000      9.800516   51687.921154    27.004633
# 22          0.000000  0.000000      9.526452   40506.471941    17.247572
# 25          0.000000  0.000000      9.437349   30218.392108    18.607664
# 10          4.427570  0.000000     11.741502   29858.639133    93.080010
# 13          0.000000  0.000000      8.838139   18462.871476   103.945135
# 23          0.000000  0.000000      9.079197   12029.936228     0.000000
# 20          0.000000  0.000000      9.329589    5019.319047   148.968455
# 7           0.000000  0.000000      8.855292    3365.010994     0.000000
# 2           0.000000  0.000000      9.033403    3008.123239  1005.668129
# 6           0.000000  0.000000      8.467215    2709.508724   816.374984
# 11          0.000000  0.000000      4.797486       4.797486     0.000000
# 16               NaN       NaN           NaN            NaN          NaN
# 18               NaN       NaN           NaN            NaN          NaN

# %%
df_combined_filtered = df_combined[(df_combined.area_ha > 8.0000) & (df_combined.Q_specific > 0.00000)]

# %%
color_dict ={ 
            "Forest": "#105c1d",
            "Agriculture": "#f1f12d",
            "Settlement":"#a92213",
            "TWI__average":"C0",
            "TWI__sum":"C0"
                }

# %%
# def calc_rmse(obs, mod):
#     return np.sum((np.array(obs)-np.array(mod))**2)
def f(x, slope, intercept):
    # y = mx + c
    return slope * x + intercept

# %%
def plot(Q, col, save=True, title=True, color_dict=color_dict):
    # plottig 
    df_plot = df_combined_filtered[[Q,col]].copy()
    df_plot.dropna(inplace=True)
    
    ax = df_plot.plot(kind='scatter', x=col, y=Q, color=color_dict[col])
    if col == "Agriculture": df_plot.plot(kind='scatter', x=col, y=Q, color='k',s=22, ax=ax, zorder=-1) # make yellow more visible
    # trend
    x = np.linspace(min(df_plot[col]),max(df_plot[col]),1000)
    slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(df_plot[col], df_plot[Q])
    plt.plot(x, f(x, slope, intercept), color="k")
    plt.annotate(f'r={r_value:.3f}',(x[len(x)//2]+(max(x)-min(x))/8,f(x[len(x)//2], slope, intercept)))
    # specifying per tupe
    if Q == "Q_specific": Q_label = "Specific Discharge (mm/d)"
    elif Q == "Q": Q_label = "Discharge l/s"
    if col[:3] == "TWI": col_label = f'{col[5:]} {col[:3]}'
    else: col_label = f'precentage {col} cover'
    
    plt.xlabel(col_label)
    plt.ylabel(Q_label)
    plt.title(f"Relation between {col_label} and \nobserved {Q_label[:-len('(mm/d)')]} per catchment")
    if save:
        plt.savefig(f'Figures\\results_{col}_vs_{Q}.png',dpi=600 )

# %%
col = 'Forest'
Q = "Q_specific"
plot(Q, col, save=True, title=True)

# %%
col = 'Settlement'
Q = "Q_specific"
plot(Q, col, save=True, title=True)

# %%
col = 'Agriculture'
Q = "Q_specific"
plot(Q, col, save=True, title=True)

# %%
col = 'TWI__average'
Q = 'Q_specific'
plot(Q, col, save=True, title=True)

# %%
col = 'TWI__sum'
Q = 'Q'
plot(Q, col, save=True, title=True)
