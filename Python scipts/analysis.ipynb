# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import glob
import scipy
import numpy as np

# %% [markdown]
# $\frac{ug}{l} * s = \frac{ugs}{l}$
#
# $ug / (ugs/l) = l/s$

# %% [markdown]
# Groups B & C used:

# %%
solution = 0.1 # g/l
solution_ug = solution * 10**6 # ug/l
solution_ug_ml_b_c = solution_ug / 10**3 # ug/ml
solution_ug_ml_b_c
# Out:
# 100.0

# %% [markdown]
# Groups A & D

# %%
solution = 2 / 5 # g/l * 20% rodamine
solution_ug = solution * 10**6 # ug/l
solution_ug_ml_a_d = solution_ug / 10**3 # ug/ml
solution_ug_ml_a_d
# Out:
# 400.0

# %%
solution_dict = {"A": solution_ug_ml_a_d,
                 "B": solution_ug_ml_b_c,
                 "C": solution_ug_ml_b_c,
                 "D": solution_ug_ml_a_d}

# %%
def plot(fname, group, zero=True, temp=True,short_title=False, subplot_ax=None):
    df = pd.read_csv(fname,delimiter="\t",skiprows=1,index_col=0, parse_dates=True)
    if subplot_ax is not None:
        assert type(subplot_ax) == matplotlib.axes._axes.Axes
        ax = [subplot_ax]
        fig = subplot_ax
    elif temp:
        fig, ax = plt.subplots(1,2, figsize=(12,5))
        df[['Temp (C)']].plot(ax=ax[1],color="C3",ls="--")
        ax[1].set_ylabel('Temp (C)')
    else:
        fig, axs = plt.subplots(1,1, figsize=(12/2,5))
        ax = [axs]
    if zero:
        zero = df['Rhodamine (ug/L)'].iloc[:2].mean()
        df['Rhodamine (ug/L)']  = df['Rhodamine (ug/L)'] - zero
    df[['Rhodamine (ug/L)']].plot(ax=ax[0])

    title = fname[:fname.find(".tab")]
    title = title.replace("\\", " ")
    
    ax[0].set_ylabel('Rhodamine (ug/L)')
    
    area = scipy.integrate.simpson(df['Rhodamine (ug/L)'].to_numpy(),dx=2)
    
    try:
        with open(fname) as fin:
            for i, row in enumerate(fin):
                if i == 0:
                    val = row[row.find("-")+2:].strip()[:-2]
                    ml_added = int(val)
    except Exception as e:
        ml_added = int(input("What was the input ml (int)"))
    
    solution_ug_ml = solution_dict[group]
    ug_added = solution_ug_ml * ml_added 
    discharge = ug_added/area 
    if short_title:
        ax[0].set_title(f'Q:{discharge:.2f} l/s with {ml_added}ml - ${int(solution_ug_ml)}\mu g/l$')
    else:
        ax[0].set_title(title + f' - Q:{discharge:.2f} l/s with {ml_added}ml - ${int(solution_ug_ml)}\mu g/l$')
    return df, fig, title

# %% [markdown]
# # A:

# %%
filesA = glob.glob("Data\Group A\*.tab")
filesA
# Out:
# ['Data\\Group A\\Location1.tab',
#  'Data\\Group A\\Location10.tab',
#  'Data\\Group A\\Location10_2.tab',
#  'Data\\Group A\\Location6.tab']

# %%
_, fig, title = plot(filesA[0], "A",temp=False)
fig.savefig(f"Figures\\{title}.png",pad_inches=0,dpi=300)

# %% [markdown]
# # B:

# %%
filesB = glob.glob("Data\Group B\*.tab")
filesB
# Out:
# ['Data\\Group B\\12a.tab',
#  'Data\\Group B\\12b.tab',
#  'Data\\Group B\\14a -second.tab',
#  'Data\\Group B\\14a.tab',
#  'Data\\Group B\\14b - second.tab',
#  'Data\\Group B\\14b.tab',
#  'Data\\Group B\\3.b.tab',
#  'Data\\Group B\\3a - third.tab',
#  'Data\\Group B\\3a.second.tab',
#  'Data\\Group B\\3a.tab',
#  'Data\\Group B\\3b - second.tab',
#  'Data\\Group B\\3b - third.tab',
#  'Data\\Group B\\4a.tab',
#  'Data\\Group B\\4b.tab']

# %%
_, _, _ = plot(filesB[2], "B",zero=False, temp=False)

# %%
_, fig, title = plot(filesB[8], "B",temp=False,zero=False)
# fig.savefig(f"Figures\\{title}.png",pad_inches=0,dpi=300)

# %% [markdown]
# subplots for report:

# %%
fig, ax = plt.subplots(1,2, figsize=(12,5), sharey=True)
fig.tight_layout()
_, output_ax, title = plot(filesB[8], "B",temp=False,zero=False,short_title=True, subplot_ax=ax[0])
_, output_ax, title = plot(filesB[4], "B",temp=False,zero=False,short_title=True, subplot_ax=ax[1])
fig.savefig("Figures\\combined_discharge_graphs.jpg")

# %% [markdown]
# ## C:

# %%
filesC = glob.glob("Data\Group C\*.tab")
filesC
# Out:
# ['Data\\Group C\\C - loc1.tab',
#  'Data\\Group C\\C - loc1b.tab',
#  'Data\\Group C\\C - loc2.tab',
#  'Data\\Group C\\C - loc2b.tab']

# %%
_, _, _ = plot(filesC[0], "C")

# %% [markdown]
# # D:

# %%
filesD = glob.glob("Data\Group D\*.tab")

# %%
filesD
# Out:
# ['Data\\Group D\\1_1st_try.tab',
#  'Data\\Group D\\1_2nd_try.tab',
#  'Data\\Group D\\Location_2.tab',
#  'Data\\Group D\\Location_3.tab']

# %%
_, _, _ = plot(filesD[3], "D")

# %%
df2, fig2, val2 = plot(filesD[2], "D")

# %%
df2, fig2, val2 = plot(filesD[2], "D")

# %%
df2, fig2, val2 = plot(filesD[3], "D")
